# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load cleaned dataset
file_path = "cleaned_student_performance.csv"
df = pd.read_csv(file_path)

# %%
# Bubble Chart: Math Score vs. Reading Score with Writing Score as Bubble Size
plt.figure(figsize=(10, 6))
plt.scatter(
    students_data["math_score"],
    students_data["reading_score"],
    s=students_data["writing_score"] * 2,  # Bubble size scaled by writing score
    alpha=0.5,
    c=students_data["writing_score"],
    cmap="viridis",
)
plt.colorbar(label="Writing Score")
plt.title("Bubble Chart: Math vs Reading Scores (Bubble Size = Writing Score)")
plt.xlabel("Math Score")
plt.ylabel("Reading Score")
plt.show()

# Count Plot: Number of Students by Gender
plt.figure(figsize=(8, 5))
sns.countplot(x="gender", data=students_data, palette="coolwarm")
plt.title("Count of Students by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# Box Plot: Math Scores by Race/Ethnicity
plt.figure(figsize=(10, 6))
sns.boxplot(x="race/ethnicity", y="math_score", data=students_data, palette="muted")
plt.title("Math Scores by Race/Ethnicity")
plt.xlabel("Race/Ethnicity")
plt.ylabel("Math Score")
plt.xticks(rotation=45)
plt.show()

# Line Plot: Average Scores Across Subjects by Parental Education Level
plt.figure(figsize=(12, 6))
average_scores = students_data.groupby("parental_level_of_education")[["math_score", "reading_score", "writing_score"]].mean()
average_scores.plot(kind="line", marker="o")
plt.title("Average Scores Across Subjects by Parental Education Level")
plt.xlabel("Parental Level of Education")
plt.ylabel("Average Score")
plt.xticks(rotation=45)
plt.legend(["Math", "Reading", "Writing"])
plt.show()

# Bar Chart: Average Math Score Based on Lunch Type
plt.figure(figsize=(8, 5))
sns.barplot(x="lunch", y="math_score", data=students_data, palette="pastel")
plt.title("Average Math Score Based on Lunch Type")
plt.xlabel("Lunch Type")
plt.ylabel("Average Math Score")
plt.show()

# Pie Chart: Proportion of Students Who Completed Test Preparation Course
plt.figure(figsize=(8, 8))
students_data["test_preparation_course"].value_counts().plot(kind="pie", autopct="%1.1f%%", colors=["lightblue", "lightcoral"])
plt.title("Proportion of Students Who Completed Test Preparation Course")
plt.ylabel("")
plt.show()

# Save the cleaned dataset
cleaned_file_path = "StudentsPerformance_Cleaned.csv"
students_data.to_csv(cleaned_file_path, index=False)
print(f"Cleaned dataset saved as {cleaned_file_path}")
# Out:
# <ipython-input-16-906d707d86e4>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="gender", data=students_data, palette="coolwarm")
# <ipython-input-16-906d707d86e4>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="race/ethnicity", y="math_score", data=students_data, palette="muted")
# <ipython-input-16-906d707d86e4>:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="lunch", y="math_score", data=students_data, palette="pastel")
# Cleaned dataset saved as StudentsPerformance_Cleaned.csv
